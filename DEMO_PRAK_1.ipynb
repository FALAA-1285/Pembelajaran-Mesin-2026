# %% [markdown]
# <a href="https://colab.research.google.com/github/FALAA-1285/Pembelajaran-Mesin-2026/blob/main/DEMO_PRAK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Konfigurasi Pada Google Colab**
# 1. Login dengan akun google, kemudian membuat notebook baru dengan klik "**+ New notebook**"
# ![image.png](data:**image**/png;base64,...)

# %% [markdown]
# 2. Memberikan judul pada notebook pada bagian pojok kiri atas.
# 3. Mengklik tombol **Connect** pada bagian kiri atas untuk menghubungkan notebook dengan perangkat komputasi ( instances ).
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Instalasi Library Baru Pada Google Colab**
# 1. menambahkan library baru yaitu aktif, dengan ketikkan perintah "*!pip install mne mne*". Kemudian klik pada cellJalankan cell dan notebook akan melakukan proses instalasi library

# %%
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 34.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# ...

# %% [markdown]
# **Konfigurasi Pada Komputer Lokal**
# 1. Mendownload dan instal Anaconda. Anaconda merupakan package instan untuk instalasi python berserta library library yang umum digunakan.
# ![image.png](data:image/png;base64,...)
# 2. melakukan konfigurasi pada environment variabel pada saat proses instalasi Anaconda. Konfigurasi ini bertujuan agak fungsi dari Anaconda yaitu conda , dapat dipanggil melalui konsol (terminal/cmd/poweshell).
# ![image.png](data:image/png;base64,...)
# 3. Membuat file baru bernama "*Praktikum1.ipynb*" pada vs code dan memastikan Pada bagian pojok kanan atas bertuliskan "base (Python 3)"
# ![image.png](data:image/png;base64,...)
