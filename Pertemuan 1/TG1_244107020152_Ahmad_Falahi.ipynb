# %% [markdown]
# <a href="https://colab.research.google.com/github/FALAA-1285/Pembelajaran-Mesin-2026/blob/main/TG1_244107020152_Ahmad_Falahi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !{sys.executable} -m pip install pyprep
# !{sys.executable} -m pip install scipy
# !{sys.executable} -m pip install wandb
# !{sys.executable} -m pip install scikit-learn

# %% [markdown]
#  **Kegunakan masing-masing library:**
#  1. pyprep : Tahap awal untuk membersihkan sinyal EKG mentah dari gangguan (artifacts) sebelum dianalisis.
#  2. scipy untuk menyediakan algoritma matematika tingkat tinggi untuk memproses sinyal digital.
#  3. wandb untuk memproses visualisasi grafik EKG.
#  4. pyECG untuk menyediakan rekaman aktivitas listrik jantung yang terdiri dari komponen gelombang P, kompleks QRS, dan gelombang T

# %% [markdown]
# **Bagian 2**
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
# **Jawab:** Salah satu tindakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan yang sering terjadi adalah penggunaan deepfake seseorang tanpa izin. Menggunakan AI untuk membuat foto, video, atau suara palsu seseorang tanpa persetujuan sangat melanggar etika karena merugikan privasi, martabat, dan reputasi orang tersebut, sebuah tindakan yang dalam konteks hukum di Indonesia dapat melanggar ketentuan Undang-Undang Informasi dan Transaksi Elektronik (UU ITE). Oleh karena itu, pedoman global dan nasional menegaskan bahwa penggunaan AI harus selalu mematuhi prinsip transparansi dan tanggung jawab untuk mencegah eksploitasi (UNESCO, 2021; Kemenkominfo, 2023).
# > Refrensi:
# * Pemerintah Republik Indonesia (2024) Undang-Undang Nomor 1 Tahun 2024 tentang Perubahan Kedua atas Undang-Undang Nomor 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE). Jakarta: Sekretariat Negara.
# * UNESCO (2021) Recommendation on the ethics of artificial intelligence. Paris: United Nations Educational, Scientific and Cultural Organization.
#
# ---
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
# **Jawab:**
# * **Jejak Karbon dan Konsumsi Listrik Masif**
# * Dampak: Pelatihan model AI menyedot daya komputasi dan listrik yang luar biasa besar, menghasilkan emisi karbon yang jauh melampaui industri konvensional jika bersumber dari bahan bakar fosil.
# * Cara Mengatasi: Mengadopsi "Green AI" (merancang algoritma yang lebih hemat daya) dan memindahkan pusat data ke lokasi dengan 100% sumber energi terbarukan.
# * **Konsumsi Air yang Sangat Tinggi**
# * Dampak: Operasional pusat data AI menghasilkan panas ekstrem yang membutuhkan jutaan liter air bersih secara terus-menerus hanya untuk sistem pendingin server.
# * Cara Mengatasi: Membangun pusat data di wilayah beriklim dingin untuk memanfaatkan udara luar sebagai pendingin alami (free cooling) dan mendaur ulang air pendingin.
# > refrensi:
# * Strubell, E., Ganesh, A. dan McCallum, A. (2019) 'Energy and policy considerations for deep learning in NLP', arXiv preprint arXiv:1906.02243.
# * Li, P., Yang, J., Islam, M.A. dan Ren, S. (2023) 'Making AI less "thirsty": Uncovering and addressing the secret water footprint of AI models', arXiv preprint arXiv:2304.03271.
